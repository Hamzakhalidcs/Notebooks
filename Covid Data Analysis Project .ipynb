# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px 
from plotly.subplots import make_subplots
from datetime import datetime

# %%
covid_df = pd.read_csv("covid_19_india .csv")

# %%
# # Just A QUICK REPORT
import pandas_profiling as pp
profile = pp.ProfileReport(covid_df)
profile

# %%
covid_df.head()
# Out:
#    Sno        Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0    1  11/08/2021  6:00 PM               Kerala                       1
# 1    2  11/08/2021  6:00 PM               Kerala                       1
# 2    3  11/08/2021  6:00 PM               Kerala                       2
# 3    4  11/08/2021  6:00 PM               Kerala                       3
# 4    5  11/08/2021  6:00 PM               Kerala                       3
#
#   ConfirmedForeignNational  Cured  Deaths  Confirmed  Unnamed: 9  Unnamed: 10  \
# 0                        0      0       0          1         NaN          NaN
# 1                        0      0       0          1         NaN          NaN
# 2                        0      0       0          2         NaN          NaN
# 3                        0      0       0          3         NaN          NaN
# 4                        0      0       0          3         NaN          NaN
#
#    Unnamed: 11 Unnamed: 12
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN

# %%
covid_df.info()

# %%
# describe() function use only for numerical columns only  
covid_df.describe()

# %%
covid_df.columns

# %%
# Removed extra columns with junk data in it..
covid_df.drop(["Sno", "Time", "ConfirmedIndianNational", "ConfirmedForeignNational"], inplace=True, axis=1)

# %%
covid_df.head()
# Out:
#          Date State/UnionTerritory  Cured  Deaths  Confirmed
# 0  11/08/2021               Kerala      0       0          1
# 1  11/08/2021               Kerala      0       0          1
# 2  11/08/2021               Kerala      0       0          2
# 3  11/08/2021               Kerala      0       0          3
# 4  11/08/2021               Kerala      0       0          3

# %%
vaccine_df = pd.read_csv("covid_vaccine_statewise.csv")

# %%
vaccine_df.head()
# Out:
#    Updated On  State  Total Doses Administered  Sessions   Sites   \
# 0  16/01/2021  India                   48276.0    3455.0   2957.0
# 1  17/01/2021  India                   58604.0    8532.0   4954.0
# 2  18/01/2021  India                   99449.0   13611.0   6583.0
# 3  19/01/2021  India                  195525.0   17855.0   7951.0
# 4  20/01/2021  India                  251280.0   25472.0  10504.0
#
#    First Dose Administered  Second Dose Administered  \
# 0                  48276.0                       0.0
# 1                  58604.0                       0.0
# 2                  99449.0                       0.0
# 3                 195525.0                       0.0
# 4                 251280.0                       0.0
#
#    Male (Doses Administered)  Female (Doses Administered)  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# 3                        NaN                          NaN
# 4                        NaN                          NaN
#
#    Transgender (Doses Administered)  ...  18-44 Years (Doses Administered)  \
# 0                               NaN  ...                               NaN
# 1                               NaN  ...                               NaN
# 2                               NaN  ...                               NaN
# 3                               NaN  ...                               NaN
# 4                               NaN  ...                               NaN
#
#    45-60 Years (Doses Administered)  60+ Years (Doses Administered)  \
# 0                               NaN                             NaN
# 1                               NaN                             NaN
# 2                               NaN                             NaN
# 3                               NaN                             NaN
# 4                               NaN                             NaN
#
#    18-44 Years(Individuals Vaccinated)  45-60 Years(Individuals Vaccinated)  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
#
#    60+ Years(Individuals Vaccinated)  Male(Individuals Vaccinated)  \
# 0                                NaN                       23757.0
# 1                                NaN                       27348.0
# 2                                NaN                       41361.0
# 3                                NaN                       81901.0
# 4                                NaN                       98111.0
#
#    Female(Individuals Vaccinated)  Transgender(Individuals Vaccinated)  \
# 0                         24517.0                                  2.0
# 1                         31252.0                                  4.0
# 2                         58083.0                                  5.0
# 3                        113613.0                                 11.0
# 4                        153145.0                                 24.0
#
#    Total Individuals Vaccinated
# 0                       48276.0
# 1                       58604.0
# 2                       99449.0
# 3                      195525.0
# 4                      251280.0
#
# [5 rows x 24 columns]

# %%
vaccine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7845 entries, 0 to 7844
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Updated On                           7845 non-null   object
#  1   State                                7845 non-null   object
#  2   Total Doses Administered             7621 non-null   float64
#  3   Sessions                             7621 non-null   float64
#  4    Sites                               7621 non-null   float64
#  5   First Dose Administered              7621 non-null   float64
#  6   Second Dose Administered             7621 non-null   float64
#  7   Male (Doses Administered)            7461 non-null   float64
#  8   Female (Doses Administered)          7461 non-null   float64
#  9   Transgender (Doses Administered)     7461 non-null   float64
#  10   Covaxin (Doses Administered)        7621 non-null   float64
#  11  CoviShield (Doses Administered)      7621 non-null   float64
#  12  Sputnik V (Doses Administered)       2995 non-null   float64
#  13  AEFI                                 5438 non-null   float64
#  14  18-44 Years (Doses Administered)     1702 non-null   float64
#  15  45-60 Years (Doses Administered)     1702 non-null   float64
#  16  60+ Years (Doses Administered)       1702 non-null   float64
#  17  18-44 Years(Individuals Vaccinated)  3733 non-null   float64
#  18  45-60 Years(Individuals Vaccinated)  3734 non-null   float64
#  19  60+ Years(Individuals Vaccinated)    3734 non-null   float64
#  20  Male(Individuals Vaccinated)         160 non-null    float64
#  21  Female(Individuals Vaccinated)       160 non-null    float64
#  22  Transgender(Individuals Vaccinated)  160 non-null    float64
#  23  Total Individuals Vaccinated         5919 non-null   float64
# dtypes: float64(22), object(2)
# memory usage: 1.4+ MB

# %%
covid_df["State/UnionTerritory"].value_counts()
# Out:
# Kerala                                      560
# Delhi                                       528
# Rajasthan                                   527
# Uttar Pradesh                               526
# Haryana                                     526
# Tamil Nadu                                  523
# Ladakh                                      523
# Jammu and Kashmir                           521
# Punjab                                      521
# Karnataka                                   520
# Maharashtra                                 520
# Andhra Pradesh                              518
# Uttarakhand                                 515
# Odisha                                      514
# Puducherry                                  512
# West Bengal                                 512
# Chhattisgarh                                511
# Chandigarh                                  511
# Gujarat                                     510
# Himachal Pradesh                            508
# Madhya Pradesh                              508
# Manipur                                     506
# Bihar                                       506
# Mizoram                                     505
# Goa                                         504
# Andaman and Nicobar Islands                 504
# Assam                                       498
# Jharkhand                                   498
# Arunachal Pradesh                           496
# Tripura                                     492
# Meghalaya                                   485
# Dadra and Nagar Haveli and Daman and Diu    461
# Nagaland                                    452
# Sikkim                                      445
# Telengana                                   426
# Lakshadweep                                 244
# Telangana                                   102
# Cases being reassigned to states             60
# Unassigned                                    3
# Bihar****                                     2
# Dadra and Nagar Haveli                        2
# Karanataka                                    1
# Himanchal Pradesh                             1
# Daman & Diu                                   1
# Maharashtra***                                1
# Madhya Pradesh***                             1
# Name: State/UnionTerritory, dtype: int64

# %%
covid_df['Date'] = pd.to_datetime(covid_df['Date'], format= '%d/%m/%Y')

# %%
covid_df.head(2)
# Out:
#         Date State/UnionTerritory  Cured  Deaths  Confirmed
# 0 2021-08-11               Kerala      0       0          1
# 1 2021-08-11               Kerala      0       0          1

# %%
# Active cases 
covid_df['Active_cases'] = covid_df['Confirmed'] - (covid_df['Cured'] + covid_df['Deaths'])

# %%
covid_df.tail()
# Out:
#             Date State/UnionTerritory    Cured  Deaths  Confirmed  \
# 18105 2020-02-03            Telangana   638410    3831     650353
# 18106 2020-02-02              Tripura    77811     773      80660
# 18107 2020-02-01          Uttarakhand   334650    7368     342462
# 18108 2020-01-31        Uttar Pradesh  1685492   22775    1708812
# 18109 2020-01-30          West Bengal  1506532   18252    1534999
#
#        Active_cases
# 18105          8112
# 18106          2076
# 18107           444
# 18108           545
# 18109         10215

# %%
# using pivot table 
statewise = pd.pivot_table(covid_df, values = ["Confirmed", "Deaths", "Cured"], index="State/UnionTerritory", aggfunc= max)

# %%
# recovery rate is basically total_cured Cases * 100 /confirmed_cases
statewise["Recovery Rate"] = statewise["Cured"] * 100/(statewise["Confirmed"])

# %%
statewise["Recovery Rate"] = statewise["Recovery Rate"].map(str) + '%'

# %%
# import numpy as np 
# statewise['Recovery Rate']  = statewise["Recovery Rate"].apply(np.ceil)

# %%
statewise["Recovery Rate"].value_counts()
# Out:
# 99.0     18
# 98.0     11
# 0.0       3
# 97.0      3
# 100.0     3
# 95.0      2
# 92.0      2
# 90.0      1
# 82.0      1
# 73.0      1
# 94.0      1
# Name: Recovery Rate, dtype: int64

# %%
# Mortality Rate is totalnumber of deaths *100 /confirmed cases
statewise["Mortaliy Rate"] = statewise['Deaths'] * 100 /statewise["Confirmed"]

# %%
statewise["Mortaliy Rate"] = statewise["Mortaliy Rate"].apply(np.ceil)

# %%
statewise["Mortaliy Rate"] = statewise["Mortaliy Rate"].map(str) + "%"

# %%
statewise.head()
# Out:
#                              Confirmed    Cured  Deaths Recovery Rate  \
# State/UnionTerritory
# Andaman and Nicobar Islands       7548     7412     129         99.0%
# Andhra Pradesh                 1985182  1952736   13564         99.0%
# Arunachal Pradesh                50605    47821     248         95.0%
# Assam                           576149   559684    5420         98.0%
# Bihar                           725279   715352    9646         99.0%
#
#                             Mortaliy Rate
# State/UnionTerritory
# Andaman and Nicobar Islands          2.0%
# Andhra Pradesh                       1.0%
# Arunachal Pradesh                    1.0%
# Assam                                1.0%
# Bihar                                2.0%

# %%
#  Sort Statewise in descending order 
statewise = statewise.sort_values(by="Confirmed", ascending=False)

# %%
# statewise

# %%
# to give a visual to pivot table
# cmap args(Purples, Greens, "Reds", "BuPu", cubehelix)
statewise.style.background_gradient(cmap="cubehelix")
# Out:
# <style  type="text/css" >
# #T_f11c2_row0_col0,#T_f11c2_row0_col1,#T_f11c2_row0_col2{
#             background-color:  #ffffff;
#             color:  #000000;
#         }#T_f11c2_row1_col0{
#             background-color:  #f6fcf8;
#             color:  #000000;
#         }#T_f11c2_row1_col1,#T_f11c2_row1_col2{
#             background-color:  #f4fcf7;
#             color:  #000000;
#         }#T_f11c2_row2_col0{
#             background-color:  #c57a76;
#             color:  #000000;
#         }#T_f11c2_row2_col1{
#             background-color:  #bf796d;
#             color:  #000000;
#         }#T_f11c2_row2_col2,#T_f11c2_row8_col2{
#             background-color:  #1a213e;
#             color:  #f1f1f1;
#         }#T_f11c2_row3_col0,#T_f11c2_row4_col1{
#             background-color:  #817a37;
#             color:  #000000;
#         }#T_f11c2_row3_col1{
#             background-color:  #847a38;
#             color:  #000000;
#         }#T_f11c2_row3_col2,#T_f11c2_row7_col1{
#             background-color:  #195d48;
#             color:  #f1f1f1;
#         }#T_f11c2_row4_col0{
#             background-color:  #7e7a36;
#             color:  #000000;
#         }#T_f11c2_row4_col2{
#             background-color:  #185b48;
#             color:  #f1f1f1;
#         }#T_f11c2_row5_col0{
#             background-color:  #577a2f;
#             color:  #000000;
#         }#T_f11c2_row5_col1{
#             background-color:  #5a7a2f;
#             color:  #000000;
#         }#T_f11c2_row5_col2{
#             background-color:  #16554b;
#             color:  #f1f1f1;
#         }#T_f11c2_row6_col0{
#             background-color:  #22693f;
#             color:  #f1f1f1;
#         }#T_f11c2_row6_col1{
#             background-color:  #256b3d;
#             color:  #f1f1f1;
#         }#T_f11c2_row6_col2,#T_f11c2_row10_col2{
#             background-color:  #1a142f;
#             color:  #f1f1f1;
#         }#T_f11c2_row7_col0{
#             background-color:  #175a49;
#             color:  #f1f1f1;
#         }#T_f11c2_row7_col2{
#             background-color:  #182f49;
#             color:  #f1f1f1;
#         }#T_f11c2_row8_col0{
#             background-color:  #154e4d;
#             color:  #f1f1f1;
#         }#T_f11c2_row8_col1{
#             background-color:  #15504d;
#             color:  #f1f1f1;
#         }#T_f11c2_row9_col0{
#             background-color:  #15474e;
#             color:  #f1f1f1;
#         }#T_f11c2_row9_col1{
#             background-color:  #15494e;
#             color:  #f1f1f1;
#         }#T_f11c2_row9_col2{
#             background-color:  #17364c;
#             color:  #f1f1f1;
#         }#T_f11c2_row10_col0,#T_f11c2_row11_col1{
#             background-color:  #192a46;
#             color:  #f1f1f1;
#         }#T_f11c2_row10_col1{
#             background-color:  #192c47;
#             color:  #f1f1f1;
#         }#T_f11c2_row11_col0,#T_f11c2_row12_col1{
#             background-color:  #192845;
#             color:  #f1f1f1;
#         }#T_f11c2_row11_col2,#T_f11c2_row25_col0{
#             background-color:  #110815;
#             color:  #f1f1f1;
#         }#T_f11c2_row12_col0{
#             background-color:  #1a2744;
#             color:  #f1f1f1;
#         }#T_f11c2_row12_col2,#T_f11c2_row22_col0{
#             background-color:  #160c1f;
#             color:  #f1f1f1;
#         }#T_f11c2_row13_col0,#T_f11c2_row13_col1{
#             background-color:  #1b1f3d;
#             color:  #f1f1f1;
#         }#T_f11c2_row13_col2{
#             background-color:  #170e23;
#             color:  #f1f1f1;
#         }#T_f11c2_row14_col0,#T_f11c2_row15_col0,#T_f11c2_row16_col1,#T_f11c2_row20_col2{
#             background-color:  #1b1c3a;
#             color:  #f1f1f1;
#         }#T_f11c2_row14_col1,#T_f11c2_row15_col1{
#             background-color:  #1b1e3b;
#             color:  #f1f1f1;
#         }#T_f11c2_row14_col2,#T_f11c2_row15_col2{
#             background-color:  #180f25;
#             color:  #f1f1f1;
#         }#T_f11c2_row16_col0{
#             background-color:  #1b1b38;
#             color:  #f1f1f1;
#         }#T_f11c2_row16_col2,#T_f11c2_row17_col2,#T_f11c2_row18_col2{
#             background-color:  #160d21;
#             color:  #f1f1f1;
#         }#T_f11c2_row17_col0,#T_f11c2_row17_col1,#T_f11c2_row18_col1{
#             background-color:  #1b1a36;
#             color:  #f1f1f1;
#         }#T_f11c2_row18_col0{
#             background-color:  #1a1835;
#             color:  #f1f1f1;
#         }#T_f11c2_row19_col0,#T_f11c2_row19_col1{
#             background-color:  #1a1631;
#             color:  #f1f1f1;
#         }#T_f11c2_row19_col2{
#             background-color:  #0b040c;
#             color:  #f1f1f1;
#         }#T_f11c2_row20_col0,#T_f11c2_row20_col1{
#             background-color:  #19132d;
#             color:  #f1f1f1;
#         }#T_f11c2_row21_col0,#T_f11c2_row21_col1{
#             background-color:  #19122b;
#             color:  #f1f1f1;
#         }#T_f11c2_row21_col2{
#             background-color:  #0f0611;
#             color:  #f1f1f1;
#         }#T_f11c2_row22_col1{
#             background-color:  #140a1b;
#             color:  #f1f1f1;
#         }#T_f11c2_row22_col2,#T_f11c2_row29_col0,#T_f11c2_row29_col1,#T_f11c2_row30_col0,#T_f11c2_row30_col1{
#             background-color:  #070206;
#             color:  #f1f1f1;
#         }#T_f11c2_row23_col0,#T_f11c2_row24_col0,#T_f11c2_row24_col1,#T_f11c2_row25_col1{
#             background-color:  #120817;
#             color:  #f1f1f1;
#         }#T_f11c2_row23_col1,#T_f11c2_row24_col2{
#             background-color:  #130919;
#             color:  #f1f1f1;
#         }#T_f11c2_row23_col2{
#             background-color:  #0e050f;
#             color:  #f1f1f1;
#         }#T_f11c2_row25_col2,#T_f11c2_row26_col0,#T_f11c2_row26_col1,#T_f11c2_row27_col0,#T_f11c2_row27_col1{
#             background-color:  #0c050e;
#             color:  #f1f1f1;
#         }#T_f11c2_row26_col2,#T_f11c2_row27_col2,#T_f11c2_row28_col0,#T_f11c2_row28_col1,#T_f11c2_row28_col2{
#             background-color:  #0a030a;
#             color:  #f1f1f1;
#         }#T_f11c2_row29_col2,#T_f11c2_row30_col2,#T_f11c2_row31_col0,#T_f11c2_row31_col1{
#             background-color:  #050205;
#             color:  #f1f1f1;
#         }#T_f11c2_row31_col2,#T_f11c2_row33_col2,#T_f11c2_row34_col1,#T_f11c2_row35_col0,#T_f11c2_row35_col1,#T_f11c2_row36_col0,#T_f11c2_row36_col1,#T_f11c2_row36_col2,#T_f11c2_row37_col0,#T_f11c2_row37_col1{
#             background-color:  #020102;
#             color:  #f1f1f1;
#         }#T_f11c2_row32_col0,#T_f11c2_row32_col1,#T_f11c2_row32_col2,#T_f11c2_row33_col0,#T_f11c2_row33_col1,#T_f11c2_row34_col0{
#             background-color:  #030103;
#             color:  #f1f1f1;
#         }#T_f11c2_row34_col2,#T_f11c2_row35_col2,#T_f11c2_row37_col2,#T_f11c2_row38_col0,#T_f11c2_row38_col1,#T_f11c2_row38_col2,#T_f11c2_row39_col0,#T_f11c2_row39_col1,#T_f11c2_row39_col2,#T_f11c2_row40_col0,#T_f11c2_row40_col1,#T_f11c2_row40_col2,#T_f11c2_row41_col0,#T_f11c2_row41_col1,#T_f11c2_row41_col2,#T_f11c2_row42_col0,#T_f11c2_row42_col1,#T_f11c2_row42_col2,#T_f11c2_row43_col0,#T_f11c2_row43_col1,#T_f11c2_row43_col2,#T_f11c2_row44_col0,#T_f11c2_row44_col1,#T_f11c2_row44_col2,#T_f11c2_row45_col0,#T_f11c2_row45_col1,#T_f11c2_row45_col2{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }</style><table id="T_f11c2_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Confirmed</th>        <th class="col_heading level0 col1" >Cured</th>        <th class="col_heading level0 col2" >Deaths</th>        <th class="col_heading level0 col3" >Recovery Rate</th>        <th class="col_heading level0 col4" >Mortaliy Rate</th>    </tr>    <tr>        <th class="index_name level0" >State/UnionTerritory</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f11c2_level0_row0" class="row_heading level0 row0" >Maharashtra</th>
#                         <td id="T_f11c2_row0_col0" class="data row0 col0" >6363442</td>
#                         <td id="T_f11c2_r

# %%
# Top 10 active cases states
top_10_active_cases = covid_df.groupby(by= 'State/UnionTerritory').max()[['Active_cases', 'Date']].sort_values(by=['Active_cases'],ascending=False).reset_index()

# %%
fig = plt.figure(figsize=(16,9))

# %%
plt.title("Top 10 States With most Active Cases in India", size=25)
# Out:
# Text(0.5, 1.0, 'Top 10 States With most Active Cases in India')

# %%
ax = sns.barplot(data = top_10_active_cases.iloc[:10], y='Active_cases', x='State/UnionTerritory', linewidth=2, edgecolor='red')

# %%
top_10_active_cases = covid_df.groupby(by= 'State/UnionTerritory').max()[['Active_cases', 'Date']].sort_values(by=['Active_cases'],ascending=False).reset_index()
fig = plt.figure(figsize=(16,9))
plt.title("Top 10 States With most Active Cases in India", size=25)
ax = sns.barplot(data = top_10_active_cases.iloc[:10], y='Active_cases', x='State/UnionTerritory', linewidth=2, edgecolor='red')

plt.xlabel("States")
plt.ylabel("Total Active Cases")
plt.show()
