# %%
import pandas as pd

# %%
df = pd.read_csv('data_sets/DataScientist.csv')

# %%
df.head(2)
# Out:
#    Unnamed: 0  index                          Job Title  \
# 0           0      0              Senior Data Scientist
# 1           1      1  Data Scientist, Product Analytics
#
#                 Salary Estimate  \
# 0  $111K-$181K (Glassdoor est.)
# 1  $111K-$181K (Glassdoor est.)
#
#                                      Job Description  Rating    Company Name  \
# 0  ABOUT HOPPER\r\n\r\nAt Hopper, we’re on a miss...     3.5   Hopper\r\n3.5
# 1  At Noom, we use scientifically proven methods ...     4.5  Noom US\r\n4.5
#
#        Location      Headquarters                    Size  Founded  \
# 0  New York, NY  Montreal, Canada   501 to 1000 employees     2007
# 1  New York, NY      New York, NY  1001 to 5000 employees     2008
#
#    Type of ownership                   Industry             Sector  \
# 0  Company - Private            Travel Agencies   Travel & Tourism
# 1  Company - Private  Health, Beauty, & Fitness  Consumer Services
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'index', 'Job Title', 'Salary Estimate',
#        'Job Description', 'Rating', 'Company Name', 'Location', 'Headquarters',
#        'Size', 'Founded', 'Type of ownership', 'Industry', 'Sector', 'Revenue',
#        'Competitors', 'Easy Apply'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 17

# %%
to_drop = ['index','Rating','Headquarters','Size','Founded','Type of ownership'
,'Revenue','Sector','Easy Apply','Competitors','Unnamed: 0']

# %%
df.drop(to_drop, inplace=True, axis=1)

# %%
df
# Out:
#                                               Job Title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 3904                                  AWS Data Engineer
# 3905                              Data Analyst â Junior
# 3906                   Security Analytics Data Engineer
# 3907                   Security Analytics Data Engineer
# 3908  Patient Safety Physician or Safety Scientist -...
#
#                    Salary Estimate  \
# 0     $111K-$181K (Glassdoor est.)
# 1     $111K-$181K (Glassdoor est.)
# 2     $111K-$181K (Glassdoor est.)
# 3     $111K-$181K (Glassdoor est.)
# 4     $111K-$181K (Glassdoor est.)
# ...                            ...
# 3904   $55K-$112K (Glassdoor est.)
# ...

# %%
df['Industry'].value_counts()
# Out:
# -1                                      546
# IT Services                             472
# Staffing & Outsourcing                  313
# Biotech & Pharmaceuticals               293
# Computer Hardware & Software            264
#                                        ...
# Sporting Goods Stores                     1
# Beauty & Personal Accessories Stores      1
# Health Fundraising Organizations          1
# Telecommunications Manufacturing          1
# Self-Storage Services                     1
# Name: Industry, Length: 96, dtype: int64

# %%
len(df[
    df['Industry'] == '-1'
]['Industry'])
# Out:
# 546

# %%
df.loc[
    df['Industry']== '-1', 'Industry'
] = 'Private'

# %%
df['Industry'].value_counts()
# Out:
# Private                                 546
# IT Services                             472
# Staffing & Outsourcing                  313
# Biotech & Pharmaceuticals               293
# Computer Hardware & Software            264
#                                        ...
# Sporting Goods Stores                     1
# Beauty & Personal Accessories Stores      1
# Health Fundraising Organizations          1
# Telecommunications Manufacturing          1
# Self-Storage Services                     1
# Name: Industry, Length: 96, dtype: int64

# %%
df.isna().sum()
# Out:
# Job Title          0
# Salary Estimate    0
# Job Description    0
# Company Name       0
# Location           0
# Industry           0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df['Job Title'].value_counts()
# Out:
# Data Scientist                                                274
# Data Engineer                                                 260
# Data Analyst                                                  246
# Senior Data Scientist                                          91
# Senior Data Analyst                                            47
#                                                              ...
# Senior Data Science Engineer                                    1
# Principle Scientist, Immunology                                 1
# Senior Research Scientist Specializing in Machine Learning      1
# Senior Scientist, Biopharm Upstream Process Development         1
# Quantitative Developer, Data & Institutional Markets            1
# Name: Job Title, Length: 2079, dtype: int64

# %%
df['Job Title'].value_counts()
# Out:
# Data Scientist                                                274
# Data Engineer                                                 260
# Data Analyst                                                  246
# Senior Data Scientist                                          91
# Senior Data Analyst                                            47
#                                                              ...
# Senior Data Science Engineer                                    1
# Principle Scientist, Immunology                                 1
# Senior Research Scientist Specializing in Machine Learning      1
# Senior Scientist, Biopharm Upstream Process Development         1
# Quantitative Developer, Data & Institutional Markets            1
# Name: Job Title, Length: 2079, dtype: int64

# %%
df['Salary Estimate']
# Out:
# 0       $111K-$181K (Glassdoor est.)
# 1       $111K-$181K (Glassdoor est.)
# 2       $111K-$181K (Glassdoor est.)
# 3       $111K-$181K (Glassdoor est.)
# 4       $111K-$181K (Glassdoor est.)
#                     ...
# 3904     $55K-$112K (Glassdoor est.)
# 3905     $55K-$112K (Glassdoor est.)
# 3906     $55K-$112K (Glassdoor est.)
# 3907     $55K-$112K (Glassdoor est.)
# 3908     $55K-$112K (Glassdoor est.)
# Name: Salary Estimate, Length: 3909, dtype: object

# %%
df['Job Title'].value_counts()
# Out:
# Data Scientist                                                274
# Data Engineer                                                 260
# Data Analyst                                                  246
# Senior Data Scientist                                          91
# Senior Data Analyst                                            47
#                                                              ...
# Senior Data Science Engineer                                    1
# Principle Scientist, Immunology                                 1
# Senior Research Scientist Specializing in Machine Learning      1
# Senior Scientist, Biopharm Upstream Process Development         1
# Quantitative Developer, Data & Institutional Markets            1
# Name: Job Title, Length: 2079, dtype: int64

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Company Name',
#        'Location', 'Industry'],
#       dtype='object')

# %%
# Removing susbtring from column 
remove  = ['(Glassdoor est.)','$','(Employer est.)',')','(']
for string in remove:
    df['Salary Estimate'] = df['Salary Estimate'].str.replace(string, '')
# Out:
# 2025-11-25 19:56:16,552 [8016] WARNING  py.warnings:110: [JupyterRequire] c:\users\pc\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   after removing the cwd from sys.path.
#
# 2025-11-25 19:56:16,563 [8016] WARNING  py.warnings:110: [JupyterRequire] c:\users\pc\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   after removing the cwd from sys.path.

# %%
df['Salary Estimate']
# Out:
# 0       111K-181K
# 1       111K-181K
# 2       111K-181K
# 3       111K-181K
# 4       111K-181K
#            ...
# 3904     55K-112K
# 3905     55K-112K
# 3906     55K-112K
# 3907     55K-112K
# 3908     55K-112K
# Name: Salary Estimate, Length: 3909, dtype: object

# %%
# split column by separtor 

df[['Estimate Minimum Salary', 'Estimate Max Salary']] = df['Salary Estimate'].str.split("-", expand=True )

# %%
df[['Salary Estimate', 'Estimate Minimum Salary', 'Estimate Max Salary']].head()
# Out:
#   Salary Estimate Estimate Minimum Salary Estimate Max Salary
# 0      111K-181K                     111K               181K
# 1      111K-181K                     111K               181K
# 2      111K-181K                     111K               181K
# 3      111K-181K                     111K               181K
# 4      111K-181K                     111K               181K

# %%
df.head()
# Out:
#                            Job Title Salary Estimate  \
# 0              Senior Data Scientist      111K-181K
# 1  Data Scientist, Product Analytics      111K-181K
# 2               Data Science Manager      111K-181K
# 3                       Data Analyst      111K-181K
# 4             Director, Data Science      111K-181K
#
#                                      Job Description  \
# 0  ABOUT HOPPER\r\n\r\nAt Hopper, we’re on a miss...
# 1  At Noom, we use scientifically proven methods ...
# 2  Decode_M\r\n\r\nhttps://www.decode-m.com/\r\n\...
# 3  Sapphire Digital seeks a dynamic and driven mi...
# 4  Director, Data Science - (200537)\r\nDescripti...
#
#                         Company Name       Location  \
# 0                      Hopper\r\n3.5   New York, NY
# 1                     Noom US\r\n4.5   New York, NY
# 2                           Decode_M   New York, NY
# 3            Sapphire Digital\r\n3.4  Lyndhurst, NJ
# 4  United Entertainment Group\r\n3.4   New York, NY
#
# ...

# %%
name = "Hopper\r\n3.5"

# %%
print(name[:-4])
# Out:
# Hopper

# %%
df['Location'] =  df['Location'].str[:-4]

# %%
df.head()
# Out:
#                            Job Title Salary Estimate  \
# 0              Senior Data Scientist      111K-181K
# 1  Data Scientist, Product Analytics      111K-181K
# 2               Data Science Manager      111K-181K
# 3                       Data Analyst      111K-181K
# 4             Director, Data Science      111K-181K
#
#                                      Job Description  \
# 0  ABOUT HOPPER\r\n\r\nAt Hopper, we’re on a miss...
# 1  At Noom, we use scientifically proven methods ...
# 2  Decode_M\r\n\r\nhttps://www.decode-m.com/\r\n\...
# 3  Sapphire Digital seeks a dynamic and driven mi...
# 4  Director, Data Science - (200537)\r\nDescripti...
#
#                         Company Name   Location                   Industry  \
# 0                      Hopper\r\n3.5   New York            Travel Agencies
# 1                     Noom US\r\n4.5   New York  Health, Beauty, & Fitness
# 2                           Decode_M   New York                    Private
# ...

# %%
df['Company Name'].str[:-5]
# Out:
# 0                                 Hopper
# 1                                Noom US
# 2                                    Dec
# 3                       Sapphire Digital
# 4             United Entertainment Group
#                       ...
# 3904                Tachyon Technologies
# 3905    Staffigo Technical Services, LLC
# 3906                      PDS Tech, Inc.
# 3907          Data Resource Technologies
# 3908                                 UCB
# Name: Company Name, Length: 3909, dtype: object

# %%
df['Company Name'] = df['Company Name'].str[:-5]

# %%
df.head()
# Out:
#                            Job Title Salary Estimate  \
# 0              Senior Data Scientist      111K-181K
# 1  Data Scientist, Product Analytics      111K-181K
# 2               Data Science Manager      111K-181K
# 3                       Data Analyst      111K-181K
# 4             Director, Data Science      111K-181K
#
#                                      Job Description  \
# 0  ABOUT HOPPER\r\n\r\nAt Hopper, we’re on a miss...
# 1  At Noom, we use scientifically proven methods ...
# 2  Decode_M\r\n\r\nhttps://www.decode-m.com/\r\n\...
# 3  Sapphire Digital seeks a dynamic and driven mi...
# 4  Director, Data Science - (200537)\r\nDescripti...
#
#                  Company Name   Location                   Industry  \
# 0                      Hopper   New York            Travel Agencies
# 1                     Noom US   New York  Health, Beauty, & Fitness
# 2                         Dec   New York                    Private
# ...

# %%
# Counting the number of skill that which require these skill in how many jobs and how much time 
skills_set = ['sql','python','power bi','tableau','excel',' r ']

# %%
import time

# %%
for skill in skills_set:
    time.sleep(1)
    print("Number of jobs that requires", skill, ':', len(df[
        (df['Job Description'].str.contains(skill, case=False)) &
        (df['Job Title'] == 'Data Analyst')
    ]))
    print("*"*40)
# Out:
# Number of jobs that requires sql : 183
# ****************************************
# Number of jobs that requires python : 75
# ****************************************
# Number of jobs that requires power bi : 30
# ****************************************
# Number of jobs that requires tableau : 63
# ****************************************
# Number of jobs that requires excel : 143
# ****************************************
# Number of jobs that requires  r  : 16
# ****************************************
