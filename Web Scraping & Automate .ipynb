# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
simpson_df = pd.read_html('https://en.wikipedia.org/wiki/List_of_The_Simpsons_episodes')

# %%
len(simpson_df)
# Out:
# 16

# %%
# there are 16 tables in the link so read specific table like that.....
simpson_df[3]
# Out:
#                                                Title      Directed by                                         Written by  Original release date
# 0                     The Force Awakens from Its Nap  David Silverman             Joel H. Cohen, Al Jean & Michael Price            May 4, 2021
# 1                   The Good, the Bart, and the Loki  David Silverman  Elisabeth Kiernan Averick, Jessica Conrad, Joh...           July 7, 2021
# 2                                       Plusaversary  David Silverman  Joel H. Cohen, Jessica Conrad, Al Jean, Loni S...      November 12, 2021
# 3                               When Billie Met Lisa  David Silverman  Elisabeth Kiernan Averick, Broti Gupta, Al Jea...         April 22, 2022
# 4                                Welcome to the Club  David Silverman  J. Stewart Burns, Joel H. Cohen, Al Jean, Chri...      September 8, 2022
# ...

# %%
simpson_df[5]
# Out:
#                                                Title                                        Directed by                                         Written by                                  Original air date                                          Prod.code                                      Ratings/Share
# 0                        "Springfield's Most Wanted"                                         Bill Brown                           Jack Parmeter & Bob Bain                                 September 17, 1995                                                NaN                                            8.4[55]
# 1  In a parody of America's Most Wanted, host Joh...  In a parody of America's Most Wanted, host Joh...  In a parody of America's Most Wanted, host Joh...  In a parody of America's Most Wanted, host Joh...  In a parody of America's Most Wanted, host Joh...  In a parody of America's Most Wanted, host Joh...
# ...

# %% [markdown]
# ## Read a CSV file from a url with Pandas

# %% [markdown]
# ### Target Website: https://www.football-data.co.uk/data.php

# %%
# reading 1 csv file from the website
df_premier21 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2223/E0.csv')

# %%
df_premier21.head()
# Out:
#   Div        Date   Time        HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR   Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  B365A    BWH   BWD   BWA    IWH   IWD   IWA    PSH   PSD   PSA    WHH  WHD   WHA    VCH  VCD   VCA   MaxH  MaxD  MaxA   AvgH  AvgD  AvgA  B365>2.5  B365<2.5  P>2.5  P<2.5  Max>2.5  Max<2.5  Avg>2.5  Avg<2.5   AHh  B365AHH  B365AHA  PAHH  PAHA  MaxAHH  MaxAHA  AvgAHH  AvgAHA  B365CH  B365CD  B365CA  BWCH  BWCD  BWCA   IWCH  IWCD  IWCA   PSCH  PSCD  PSCA   WHCH  WHCD  WHCA   VCCH  VCCD  VCCA  MaxCH  MaxCD  MaxCA  AvgCH  AvgCD  AvgCA  B365C>2.5  B365C<2.5  PC>2.5  PC<2.5  MaxC>2.5  MaxC<2.5  AvgC>2.5  AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA
# ...

# %%
df_premier21.tail()
# Out:
#     Div        Date   Time       HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR    Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  B365A   BWH   BWD   BWA   IWH   IWD   IWA   PSH   PSD   PSA   WHH   WHD   WHA   VCH   VCD   VCA  MaxH  MaxD  MaxA  AvgH  AvgD  AvgA  B365>2.5  B365<2.5  P>2.5  P<2.5  Max>2.5  Max<2.5  Avg>2.5  Avg<2.5   AHh  B365AHH  B365AHA  PAHH  PAHA  MaxAHH  MaxAHA  AvgAHH  AvgAHA  B365CH  B365CD  B365CA  BWCH  BWCD  BWCA  IWCH  IWCD  IWCA  PSCH  PSCD  PSCA  WHCH  WHCD  WHCA  VCCH  VCCD  VCCA  MaxCH  MaxCD  MaxCA  AvgCH  AvgCD  AvgCA  B365C>2.5  B365C<2.5  PC>2.5  PC<2.5  MaxC>2.5  MaxC<2.5  AvgC>2.5  AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA
# ...

# %%
# rename columns 
df_premier21.rename(columns={'FTHG' : 'home_goals', 'FTAG' : 'Away_goals'}, inplace=True)

# %% [markdown]
# ## Extract Tables From PDFs

# %%
# pip install ghostscript
# pip install camelot-py
# pip install camelot-py[cv] 
# pip install camelot-py[base]

# %%
# pip --help will show you the options use with pip 
# pip list is use to check installed packages in environment

# %%
import camelot

# %%
# read the flle like that 
tables = camelot.read_pdf('FIRM_Database_Technical_Reference_Feb_2019.pdf', pages='1')

# %%
tables.export('foo.csv', f='csv', compress=True)
tables[0].to_csv('foo.csv')

# %% [markdown]
# ## HTML Tags & Elements

# %%
eval("9 + 5")
# Out:
# 14
