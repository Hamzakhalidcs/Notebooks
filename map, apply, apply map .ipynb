# %%
import pandas as pd 
import numpy as np 
import re

# %%
train = pd.read_csv('http://bit.ly/kaggletrain')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train["First_Name"] = train["Name"].str.split(',')

# %%
train["Name1_test"] = train["Name"].str.split(',')[0][0]

# %%
train["Name1"] = train["First_Name"][0][0]

# %%
train[["Name", "First_Name", "Name1", "Name1_test"]].head()
# Out:
#                                                 Name  \
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                           Allen, Mr. William Henry
#
#                                           First_Name   Name1 Name1_test
# 0                         [Braund,  Mr. Owen Harris]  Braund     Braund
# 1  [Cumings,  Mrs. John Bradley (Florence Briggs ...  Braund     Braund
# 2                          [Heikkinen,  Miss. Laina]  Braund     Braund
# 3    [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]  Braund     Braund
# 4                        [Allen,  Mr. William Henry]  Braund     Braund

# %%
# Name contains Harris
train[
    train["Name"].str.contains("Harris", flags=re.I, regex=True)
][["Name", "Name1_test"]]
# Out:
#                                              Name Name1_test
# 0                         Braund, Mr. Owen Harris     Braund
# 62                    Harris, Mr. Henry Birkhardt     Braund
# 219                            Harris, Mr. Walter     Braund
# 230  Harris, Mrs. Henry Birkhardt (Irene Wallach)     Braund
# 263                         Harrison, Mr. William     Braund
# 570                            Harris, Mr. George     Braund

# %%
train[
    train["Name"].str.contains("Harris", flags=re.I, regex=True)
]["Name"].head()
# Out:
# 0                           Braund, Mr. Owen Harris
# 62                      Harris, Mr. Henry Birkhardt
# 219                              Harris, Mr. Walter
# 230    Harris, Mrs. Henry Birkhardt (Irene Wallach)
# 263                           Harrison, Mr. William
# Name: Name, dtype: object

# %%
train["Name"].str.split(',')
# Out:
# 0                             [Braund,  Mr. Owen Harris]
# 1      [Cumings,  Mrs. John Bradley (Florence Briggs ...
# 2                              [Heikkinen,  Miss. Laina]
# 3        [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]
# 4                            [Allen,  Mr. William Henry]
#                              ...
# 886                             [Montvila,  Rev. Juozas]
# 887                      [Graham,  Miss. Margaret Edith]
# 888          [Johnston,  Miss. Catherine Helen "Carrie"]
# 889                             [Behr,  Mr. Karl Howell]
# 890                               [Dooley,  Mr. Patrick]
# Name: Name, Length: 891, dtype: object

# %%
train.filter(regex="Na")
# Out:
#                                                   Name  \
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 886                              Montvila, Rev. Juozas
# 887                       Graham, Miss. Margaret Edith
# 888           Johnston, Miss. Catherine Helen "Carrie"
# 889                              Behr, Mr. Karl Howell
# 890                                Dooley, Mr. Patrick
#
#                                             First_Name   Name1 Name1_test
# 0                           [Braund,  Mr. Owen Harris]  Braund     Braund
# 1    [Cumings,  Mrs. John Bradley (Florence Briggs ...  Braund     Braund
# 2                            [Heikkinen,  Miss. Laina]  Braund     Braund
# ...

# %%
train[train.eq(23)][["Name", "Age"]]
# Out:
#     Name  Age
# 0    NaN  NaN
# 1    NaN  NaN
# 2    NaN  NaN
# 3    NaN  NaN
# 4    NaN  NaN
# ..   ...  ...
# 886  NaN  NaN
# 887  NaN  NaN
# 888  NaN  NaN
# 889  NaN  NaN
# 890  NaN  NaN
#
# [891 rows x 2 columns]

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# use map function to change the value in the column 
train['sex_num'] = train.Sex.map({'female' : 0, 'male' : 1})

# %%
train.loc[0:4, ['Sex', 'sex_num']].head()
# Out:
#       Sex  sex_num
# 0    male        1
# 1  female        0
# 2  female        0
# 3  female        0
# 4    male        1

# %%
# Add new column for the length of Name column record len
train["Name_length"] = train.Name.apply(len)

# %%
train[["Name", "Name_length"]].head()
# Out:
#                                                 Name  Name_length
# 0                            Braund, Mr. Owen Harris           23
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...           51
# 2                             Heikkinen, Miss. Laina           22
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)           44
# 4                           Allen, Mr. William Henry           24

# %%
train.iloc[
    train["Name_length"]
]
# Out:
#     PassengerId  Survived  Pclass  \
# 23           24         1       1
# 51           52         0       3
# 22           23         1       3
# 44           45         1       3
# 24           25         0       3
# ..          ...       ...     ...
# 21           22         1       2
# 28           29         1       3
# 40           41         0       3
# 21           22         1       2
# 19           20         1       3
#
#                                               Name     Sex   Age  SibSp  \
# 23                    Sloper, Mr. William Thompson    male  28.0      0
# 51                    Nosworthy, Mr. Richard Cater    male  21.0      0
# 22                     McGowan, Miss. Anna "Annie"  female  15.0      0
# 44                   Devaney, Miss. Margaret Delia  female  19.0      0
# 24                   Palsson, Miss. Torborg Danira  female   8.0      3
# ..                                             ...     ...   ...    ...
# ...

# %%
# change column value using condition
train.loc[
    train["Name_length"] == 24, "Name_length"
] = 23

# %%
type(train.Name_length)
# Out:
# pandas.core.series.Series

# %%
# finding the value if you dont know the column Name
train[train.eq(23).any(1)].head()
# Out:
#     PassengerId  Survived  Pclass                      Name     Sex   Age  \
# 0             1         0       3   Braund, Mr. Owen Harris    male  22.0
# 4             5         0       3  Allen, Mr. William Henry    male  35.0
# 6             7         0       1   McCarthy, Mr. Timothy J    male  54.0
# 11           12         1       1  Bonnell, Miss. Elizabeth  female  58.0
# 19           20         1       3   Masselmani, Mrs. Fatima  female   NaN
#
#     SibSp  Parch     Ticket     Fare Cabin Embarked  sex_num  Name_length
# 0       1      0  A/5 21171   7.2500   NaN        S        1           23
# 4       0      0     373450   8.0500   NaN        S        1           23
# 6       0      0      17463  51.8625   E46        S        1           23
# 11      0      0     113783  26.5500  C103        S        0           23
# 19      0      0       2649   7.2250   NaN        C        0           23

# %%
train[
    train["Name_length"]==23
].head(2)
# Out:
#    PassengerId  Survived  Pclass                      Name   Sex   Age  SibSp  \
# 0            1         0       3   Braund, Mr. Owen Harris  male  22.0      1
# 4            5         0       3  Allen, Mr. William Henry  male  35.0      0
#
#    Parch     Ticket  Fare Cabin Embarked  sex_num  Name_length
# 0      0  A/5 21171  7.25   NaN        S        1           23
# 4      0     373450  8.05   NaN        S        1           23

# %%
# To round the figure
train["Fare_ceil"] = train.Fare.apply(np.ceil)

# %%
train[['Fare', 'Fare_ceil']].head()
# Out:
#       Fare  Fare_ceil
# 0   7.2500        8.0
# 1  71.2833       72.0
# 2   7.9250        8.0
# 3  53.1000       54.0
# 4   8.0500        9.0

# %%
# split on , in Names column
train.Name.str.split(',').head()
# Out:
# 0                           [Braund,  Mr. Owen Harris]
# 1    [Cumings,  Mrs. John Bradley (Florence Briggs ...
# 2                            [Heikkinen,  Miss. Laina]
# 3      [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]
# 4                          [Allen,  Mr. William Henry]
# Name: Name, dtype: object

# %%
train["Name_list"] = train["Name"].str.split(',')

# %%
train["first_name"] = train["Name_list"].str[0]

# %%
train["last_name"] = train["Name_list"].str[1]

# %%
# same work can do using function
def get_element(my_list, position):
    return my_list[position]

# %%
train["first_name_fun"] = train["Name"].str.split(',').apply(get_element, position=0)

# %%
# same work using lambda function
train["first_name_lambda"] = train.Name.str.split(',').apply(lambda x:x[0]).head()

# %%
train[["Name", "Name_list", "first_name", "first_name_fun", "last_name", "first_name_lambda"]].head()
# Out:
#                                                 Name  \
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                           Allen, Mr. William Henry
#
#                                            Name_list first_name  \
# 0                         [Braund,  Mr. Owen Harris]     Braund
# 1  [Cumings,  Mrs. John Bradley (Florence Briggs ...    Cumings
# 2                          [Heikkinen,  Miss. Laina]  Heikkinen
# 3    [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]   Futrelle
# 4                        [Allen,  Mr. William Henry]      Allen
#
#   first_name_fun                                    last_name  \
# 0         Braund                              Mr. Owen Harris
# 1        Cumings   Mrs. John Bradley (Florence Briggs Thayer)
# 2      Heikkinen                                  Miss. Laina
# ...

# %%
train["First_Name"] = train["Name"].str.split(',').apply(lambda x:x[0])

# %% [markdown]
# ### Drinks DF

# %%
drink_df = pd.read_csv("http://bit.ly/drinksbycountry")

# %%
drink_df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
# to get max val in all columns iterate over rows 
drink_df.loc[:, 'beer_servings':'wine_servings'].apply(max, axis=0)
# Out:
# beer_servings      376
# spirit_servings    438
# wine_servings      370
# dtype: int64

# %%
drink_df[
    drink_df["beer_servings"] == 376
]["country"]
# Out:
# 117    Namibia
# Name: country, dtype: object

# %%
# to get max value in column wise mean left to right in a row
drink_df.loc[:, 'beer_servings':'wine_servings'].apply(max, axis=1)
# Out:
# 0        0
# 1      132
# 2       25
# 3      312
# 4      217
#       ...
# 188    333
# 189    111
# 190      6
# 191     32
# 192     64
# Length: 193, dtype: int64

# %%
# to check in right to left which col is max 
drink_df.loc[:, 'beer_servings':'wine_servings'].apply(np.argmax, axis=1)
# not getting the actual result
# Out:
# 0      0
# 1      1
# 2      0
# 3      2
# 4      0
#       ..
# 188    0
# 189    0
# 190    0
# 191    0
# 192    0
# Length: 193, dtype: int64

# %%
# using applymap function to deal in all_values of dataframe
drink_df.loc[:, 'beer_servings':'wine_servings'].applymap(float)
# Out:
#      beer_servings  spirit_servings  wine_servings
# 0              0.0              0.0            0.0
# 1             89.0            132.0           54.0
# 2             25.0              0.0           14.0
# 3            245.0            138.0          312.0
# 4            217.0             57.0           45.0
# ..             ...              ...            ...
# 188          333.0            100.0            3.0
# 189          111.0              2.0            1.0
# 190            6.0              0.0            0.0
# 191           32.0             19.0            4.0
# 192           64.0             18.0            4.0
#
# [193 rows x 3 columns]

# %%
# using applymap funtion to deal in all values of data frame
drink_df.loc[:, 'beer_servings':'wine_servings'].applymap(float)
# Out:
#      beer_servings  spirit_servings  wine_servings
# 0              0.0              0.0            0.0
# 1             89.0            132.0           54.0
# 2             25.0              0.0           14.0
# 3            245.0            138.0          312.0
# 4            217.0             57.0           45.0
# ..             ...              ...            ...
# 188          333.0            100.0            3.0
# 189          111.0              2.0            1.0
# 190            6.0              0.0            0.0
# 191           32.0             19.0            4.0
# 192           64.0             18.0            4.0
#
# [193 rows x 3 columns]

# %%
# apply map to some specific column 
drink_df.loc[:, 'beer_servings':'wine_servings']= drink_df.loc[:, 'beer_servings':'wine_servings'].applymap(float)

# %%
import requests
url = "https://w3schools.com/python/demopage.htm"

x= requests.get(url)
print(x.text)
# Out:
# <!DOCTYPE html>
# <html>
# <body>
#
# <h1>This is a Test Page</h1>
#
# </body>
# </html>

# %%
import requests

url = 'https://www.w3schools.com/python/demopage.php'
myobj = {'somekey': 'somevalue'}

x = requests.post(url, json = myobj)

print(x.text)

# %%
import requests

url = "https://www.w3schools.com/python/demopage.php"
data  = {"Name" : "Johnson"}

x = requests.post(url, json=data)
print(x.text)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# c:\users\pc\appdata\local\programs\python\python37\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# c:\users\pc\appdata\local\programs\python\python37\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# c:\users\pc\appdata\local\programs\python\python37\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     751     addrlist = []
# --> 752     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# ...

# %%
list_2 = [1,2,3,4]
list_2[0] = 3
list_2
# Out:
# [3, 2, 3, 4]

# %%
tuple_12 = (1, 2, 4)
tuple_lst = list(tuple_12)
tuple_lst[0] = 4
tuple_12 = tuple(tuple_lst)
print(tuple_12)
# Out:
# (4, 2, 4)
