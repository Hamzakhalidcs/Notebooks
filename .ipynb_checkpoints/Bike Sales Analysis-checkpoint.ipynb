# %%
import pandas as pd

# %%
df = pd.read_excel("Excel Project Dataset.xlsx", sheet_name="bike_buyers")

# %%
df.head()
# Out:
#       ID Marital Status Gender  Income  Children        Education  \
# 0  12496              M      F   40000         1        Bachelors
# 1  24107              M      M   30000         3  Partial College
# 2  14177              M      M   80000         5  Partial College
# 3  24381              S      M   70000         0        Bachelors
# 4  25597              S      M   30000         0        Bachelors
#
#        Occupation Home Owner  Cars Commute Distance   Region  Age  \
# 0  Skilled Manual        Yes     0        0-1 Miles   Europe   42
# 1        Clerical        Yes     1        0-1 Miles   Europe   43
# 2    Professional         No     2        2-5 Miles   Europe   60
# 3    Professional        Yes     1       5-10 Miles  Pacific   41
# 4        Clerical         No     0        0-1 Miles   Europe   36
#
#   Purchased Bike
# 0             No
# 1             No
# 2             No
# 3            Yes
# 4            Yes

# %%
df["Marital Status"] = df["Marital Status"].map({"M":"Married", "S":"Single"})

# %%
df.head()
# Out:
#       ID Marital Status Gender  Income  Children        Education  \
# 0  12496        Married      F   40000         1        Bachelors
# 1  24107        Married      M   30000         3  Partial College
# 2  14177        Married      M   80000         5  Partial College
# 3  24381         Single      M   70000         0        Bachelors
# 4  25597         Single      M   30000         0        Bachelors
#
#        Occupation Home Owner  Cars Commute Distance   Region  Age  \
# 0  Skilled Manual        Yes     0        0-1 Miles   Europe   42
# 1        Clerical        Yes     1        0-1 Miles   Europe   43
# 2    Professional         No     2        2-5 Miles   Europe   60
# 3    Professional        Yes     1       5-10 Miles  Pacific   41
# 4        Clerical         No     0        0-1 Miles   Europe   36
#
#   Purchased Bike
# 0             No
# 1             No
# 2             No
# 3            Yes
# 4            Yes

# %%
df["Gender"] = df["Gender"].map({"F":"Female", "M":"Male"})

# %%
df.head()
# Out:
#       ID Marital Status  Gender  Income  Children        Education  \
# 0  12496        Married  Female   40000         1        Bachelors
# 1  24107        Married    Male   30000         3  Partial College
# 2  14177        Married    Male   80000         5  Partial College
# 3  24381         Single    Male   70000         0        Bachelors
# 4  25597         Single    Male   30000         0        Bachelors
#
#        Occupation Home Owner  Cars Commute Distance   Region  Age  \
# 0  Skilled Manual        Yes     0        0-1 Miles   Europe   42
# 1        Clerical        Yes     1        0-1 Miles   Europe   43
# 2    Professional         No     2        2-5 Miles   Europe   60
# 3    Professional        Yes     1       5-10 Miles  Pacific   41
# 4        Clerical         No     0        0-1 Miles   Europe   36
#
#   Purchased Bike
# 0             No
# 1             No
# 2             No
# 3            Yes
# 4            Yes

# %%
df.columns.values
# Out:
# array(['ID', 'Marital Status', 'Gender', 'Income', 'Children',
#        'Education', 'Occupation', 'Home Owner', 'Cars',
#        'Commute Distance', 'Region', 'Age', 'Purchased Bike'],
#       dtype=object)

# %%
df["Commute Distance"].value_counts()
# Out:
# 0-1 Miles     378
# 5-10 Miles    197
# 1-2 Miles     176
# 2-5 Miles     162
# 10+ Miles     113
# Name: Commute Distance, dtype: int64

# %%
# df = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two',
#                            'two'],
#                    'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
#                    'baz': [1, 2, 3, 4, 5, 6],
#                    'zoo': ['x', 'y', 'z', 'q', 'w', 't']})

# df.pivot(index='foo', columns='bar', values='baz')

# %%
df.head()
# Out:
#       ID Marital Status  Gender  Income  Children        Education  \
# 0  12496        Married  Female   40000         1        Bachelors
# 1  24107        Married    Male   30000         3  Partial College
# 2  14177        Married    Male   80000         5  Partial College
# 3  24381         Single    Male   70000         0        Bachelors
# 4  25597         Single    Male   30000         0        Bachelors
#
#        Occupation Home Owner  Cars Commute Distance   Region  Age  \
# 0  Skilled Manual        Yes     0        0-1 Miles   Europe   42
# 1        Clerical        Yes     1        0-1 Miles   Europe   43
# 2    Professional         No     2        2-5 Miles   Europe   60
# 3    Professional        Yes     1       5-10 Miles  Pacific   41
# 4        Clerical         No     0        0-1 Miles   Europe   36
#
#   Purchased Bike
# 0             No
# 1             No
# 2             No
# 3            Yes
# 4            Yes

# %%
df.pivot(index="ID", columns="Gender")["Gender"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-433e6f4ce9bd> in <module>
# ----> 1 df.pivot(index="ID", columns="Gender")["Gender"]
#
# c:\users\pc\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    6877         from pandas.core.reshape.pivot import pivot
#    6878
# -> 6879         return pivot(self, index=index, columns=columns, values=values)
#    6880
#    6881     _shared_docs[
#
# c:\users\pc\appdata\local\programs\python\python37\lib\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     459         else:
#     460             indexed = data._constructor_sliced(data[values]._values, index=index)
# --> 461     return indexed.unstack(columns)
#     462
#     463
#
# ...

# %%
# abc =pd.pivot_table(df, values='ID', index=['Gender',columns=['Education'])

# %%
table = pd.pivot_table(df,index=['Gender','Education'])
table
# Out:
#                                   Age      Cars  Children            ID  \
# Gender Education
# Female Bachelors            45.793333  1.400000  1.880000  19621.460000
#        Graduate Degree      42.946809  0.574468  1.957447  19313.691489
#        High School          45.130952  1.809524  2.178571  20997.345238
#        Partial College      43.723881  1.432836  1.798507  20152.514925
#        Partial High School  39.743590  2.051282  1.538462  19889.435897
# Male   Bachelors            44.739130  1.453416  1.944099  19813.366460
#        Graduate Degree      46.802469  0.888889  2.037037  19222.629630
#        High School          43.460000  1.890000  1.760000  20301.270000
#        Partial College      42.416667  1.465278  1.930556  19799.763889
#        Partial High School  44.410256  2.076923  1.538462  22090.000000
#
#                                   Income
# Gender Education
# Female Bachelors            64266.666667
#        Graduate Degree      63297.872340
# ...

# %%
+
