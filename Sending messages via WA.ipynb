# %%
import pywhatkit as pwk
import datetime

# %%
# Defing message and phone-number
phone_number = "+923153459800"
message  ="Hello ! This is an automated message sent using python"

# %%
now = datetime.datetime.now()

# %%
time_hour = now.hour

# %%
time_hour
# Out:
# 22

# %%
time_minute =now.minute+1

# %%
time_minute
# Out:
# 44

# %%
send_message = pwk.sendwhatmsg(phone_number, message, time_hour, time_minute)
# Out:
# In 0 Seconds WhatsApp will open and after 15 Seconds Message will be Delivered!
