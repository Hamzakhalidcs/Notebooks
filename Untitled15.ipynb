# %%
import pandas as pd

# %%
df = pd.read_excel('data_sets/QQuote Hiring Tire Test Data.xlsx')

# %%
df.head()
# Out:
#   Category                                     Description Load Speed  \
# 0   WINTER                YOKOHAMA-ICEGUARD G075-255/55R18  109     T
# 1   WINTER                   BRIDGESTONE-BLIZZAK-255/55R18  109     T
# 2   WINTER      MICHELIN-MICHELIN X-ICE 2 ZP (T)-255/55R18  109     T
# 3   WINTER  MICHELIN-MICHELIN LATITUDE X-ICE XI2-255/55R18  109     T
# 4   WINTER       MICHELIN-MICHELIN X-ICE NORTH 4-255/55R18  109     T
#
#        Alias Part     MGF Part  Dealer Cost  Default Price  Unnamed: 8  \
# 0  'YOK110175118"  '110175118"       374.99         487.49         NaN
# 1   'C0BFC015879"     '015879"       441.90         574.47         NaN
# 2    'C0MNA40961"      '40961"       436.42         567.35         NaN
# 3    'C0MNA49952"      '49952"       528.61         687.19         NaN
# 4    'C0MNA67330"      '67330"       276.99         360.09         NaN
#
#    Trimmed Alias Trimmed Part #
# 0  'YOK110175118     '110175118
# 1            NaN            NaN
# ...

# %%
df1 = pd.read_excel('data_sets/QQuote Hiring Tire Format Sheet (1).xlsx')

# %%
df1.head()
# Out:
#   Manuf.Part #          Alias    Cost  Default Price  Load Index Speed Rating
# 0   '110175118  'YOK110175118  374.99         487.49         109            T
