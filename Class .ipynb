# %%
class Person:
    
    def set_data(self, name):
        self.name = name
    
    def show(self):
        print("Name is :", self.name)

# %%
p1 = Person()
p1.set_data("Hamza")
p1.show()
# Out:
# Name is : Hamza

# %%
class Person:
    
    def set_data(self, name):
        self.name = name
        
    def show(self):
        print("Name is :", self.name)

# %%
p1 = Person()

# %%
p1.set_data("Noor Ul Hassan")

# %%
p1.show()
# Out:
# Name is : Noor Ul Hassan

# %%
p2  = Person()
p2.set_data("Mustafa")
p2.show()
# Out:
# Name is : Mustafa

# %% [markdown]
# ### Now add age to the class and set age as well in this class and use object to use these methods

# %%
class Person:
    
    def set_data(self, name, age):
        self.name = name
        self.age = age
        
    def show_data(self):
        print("Name is :", self.name)
        print("Age is :", self.age)
        
    def check_age(self):
        if self.age>18:
            print("Adult")
        else:
            print("Minor")

# %%
name = Person()
name.set_data("Hamza", 25)
name.show_data()
# Out:
# Name is : Hamza
# Age is : 25

# %%
p1.show()
print("*"*20)
p2.show()
print("*"*20)
name.show_data()
# Out:
# Name is : Noor Ul Hassan
# ********************
# Name is : Mustafa
# ********************
# Name is : Hamza
# Age is : 25

# %%
name.show_data()
# Out:
# Name is : Hamza
# Age is : 25

# %%
name.check_age()
# Out:
# Adult

# %%
class Person:
    
    def set_data(self, name, age):
        self.name = name
        self.age = age
        
    def show_data(self):
        print("My name is :", self.name)
        print("My age is :", self.age)
        
#     Add a simple logic here to check whether the person is adult or not 

    def check_age(self):
        if self.age>18:
            print("The Person is Adult")
        else :
            print("The person is not Adult")

# %%
per = Person()

# %%
per.set_data("Aizaz", 23)

# %%
per.show_data()
# Out:
# My name is : Aizaz
# My age is : 23

# %%
per.check_age()
# Out:
# The Person is Adult

# %%
class Student:
    
    def set_data(self, name, marks):
        self.name = name
        self.marks = marks
        
    def show_data(self):
        print("Name", self.name)
        print("Age", self.marks)
        
    def chk_marks(self):
        if self.marks>50:
            print("PASS")
        else:
            print("FAIL")

# %%
s1 = Student()

# %%
s1.set_data("Nawaz", 39)

# %%
s1.show_data()
# Out:
# Name Nawaz
# Age 39

# %%
s1.chk_marks()
# Out:
# FAIL

# %% [markdown]
# #### Now with the cleaner way __init__

# %%
class Person:
    
    def __init__(self, name, age):
        self.name = name
        self.age = age
    
    def show(self):
        print("Name is :", self.name)
        print("Age is :", self.age)

# %%
p1 = Person("Hamza", 28)

# %%
p1.show()
# Out:
# Name is : Hamza
# Age is : 28

# %% [markdown]
# ### Task: Create a Class car with init and set car and color using init method

# %%
class Car:
    
    def __init__(self, name, color):
        self.name = name
        self.color = color
        
    def show(self):
        print("Car is :", self.name)
        print("color is :", self.color)

# %%
c1 = Car("Suzuki", "White")

# %%
c1.show()
# Out:
# Car is : Suzuki
# color is : White

# %% [markdown]
# ### Mini challenge

# %%
class Student:
    
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks
        
    def show(self):
        print("Name is ", self.name)
        print("Marks is :", self.marks)
    
    def check_result(self):
        if self.marks>50:
            print("PASS")
        else:
            print("FAIL")

# %%
S1 = Student("Hamza", 59)

# %%
S1.show()
# Out:
# Name is  Hamza
# Marks is : 59

# %%
S1.check_result()
# Out:
# PASS

# %% [markdown]
# ### Improved version of above code

# %%
class Student:
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks 
        
    def show(self):
        print(f"Name is {self.name}")
        print(f"Marks is {self.marks}")
        
    def check_result(self):
        return "PASS" if self.marks>50 else "FAIL"
        
        
    def checking_grade(self):
        if self.marks>80:
            return "A"
        
        elif self.marks>=60:
            return "B"
        
        else self.marks>=50:
            return "C"

# %%
s1 = Student("Hamza", 60)

# %%
s1.show()
# Out:
# Name is Hamza
# Marks is 60

# %%
result = s1.check_result()

# %%
print(result)
# Out:
# PASS

# %%
checking =s1.checking_grade()

# %%
checking
# Out:
# 'B'

# %%
class Student:
    
    def __init__(self, name, age, marks):
        self.name = name
        self.age = age
        self.marks = marks
        
    def show_data(self):
        print(f"Name is : {self.name}")
        print(f"Age is : {self.age}")
        print(f"Marks :{self.marks}")
        
    def chk_result(self):
        return "PASS" if self.marks>50 else "FAIL"
    
    def chk_grades(self):
        if self.marks>=80:
            return "A"
        
        elif self.marks>=60:
            return "B"
        
        else:
            return "C"

# %%
st = Student("Hamza", 12, 75)

# %%
st.show_data()
# Out:
# Name is : Hamza
# Age is : 12
# Marks :75

# %%
st.chk_result()
# Out:
# 'PASS'

# %%
st.chk_grades()
# Out:
# 'B'

# %% [markdown]
# #### Now Use a child Class and Inheritance

# %%
class GraduateStudent(Student):
    def degree(self):
        print("Degree : Master")

# %%
g1 = GraduateStudent("Hamza", 23, 60)

# %%
g1.show_data()
# Out:
# Name is : Hamza
# Age is : 23
# Marks :60

# %%
g1.degree()
# Out:
# Degree : Master

# %%
# ADD more logic to use all the parents methods 

class GraduateStudents(Student):
    
    def scholarship(self):
        if self.marks>80:
            return "ScholarShip"
        else:
            return "No ScholarShip"

# %%
g1 = GraduateStudents("Hamza", 34, 79)

# %%
g1.show_data()
# Out:
# Name is : Hamza
# Age is : 34
# Marks :79

# %%
g1.chk_result()
# Out:
# 'PASS'

# %%
g1.chk_grades()
# Out:
# 'B'

# %%
g1.scholarship()
# Out:
# 'No ScholarShip'

# %% [markdown]
# ### Task for using the Child class

# %%
class Person:
    
    def __init__(self, name):
        self.name = name
    
    def show_name(self):
        print(f"Name is {self.name}")
        
class Employee(Person):
    def __init__(self, name, salary):
        super().__init__(name) #call Parent Constructor
        self.salary = salary 
        
    def show_salary(self):
        print(f"Salary is {self.salary}")

# %%
e1 = Employee("Hamza", 50000)

# %%
e1.show_name()
# Out:
# Name is Hamza

# %%
e1.show_salary()
# Out:
# Salary is 50000

# %%
class Person:
    
    def __init__(self, name):
        self.name = name
        
    def show_name(self):
        print(f"Name is {self.name}")
        
class Employee(Person):
    def __init__(self, name, salary):
        super().__init__(name)
        self.salary = salary
        
    def show_Salary(self):
        print(f"Salary is {self.salary}")

# %%
e1 = Employee("Hamza", 50000)

# %%
e1.show_name()
# Out:
# Name is Hamza

# %%
e1.show_Salary()
# Out:
# Salary is 50000

# %% [markdown]
# ### Method overriding

# %%
class Person:
    def show(self):
        print("Parent Call")
        
class Employee(Person):
    def show(self):
        print("Child Call")

# %%
# When want to get parent function as well
class Employee(Person):
    def show(self):
        super().show()
        print("Child Call As Well")

# %%
e1 = Employee()

# %%
e1.show()
# Out:
# Parent Call
# Child Call As Well

# %% [markdown]
# ### Your Quick Practice

# %%
class Animal:
    
    def sound(self):
        print("some sound")
        
class Dog(Animal):
    
    def sound(self):
        super().sound()
        print("Bark")

# %%
a1 = Dog()

# %%
a1.sound()
# Out:
# some sound
# Bark

# %% [markdown]
# ### Mini Project (Final Practice)
#
# ##### We’ll build:
# #### Multiple students
# #### Store them
# #### Loop through them
# ### Show results
