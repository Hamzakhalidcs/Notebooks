# %%
import pandas as pd

# %%
df = pd.read_csv("annual_deaths_by_causes.csv")

# %%
df.head()
# Out:
#        country code  year  meningitis  alzheimer's_diesease  \
# 0  Afghanistan  AFG  2007      2933.0                1402.0
# 1  Afghanistan  AFG  2008      2731.0                1424.0
# 2  Afghanistan  AFG  2009      2460.0                1449.0
# 3  Afghanistan  AFG  2011      2327.0                1508.0
# 4  Afghanistan  AFG  2012      2254.0                1544.0
#
#    parkinson's_disease  nutritional_deficiency  malaria  drowning  \
# 0                450.0                  2488.0    393.0    2127.0
# 1                455.0                  2277.0    255.0    1973.0
# 2                460.0                  2040.0    239.0    1852.0
# 3                473.0                  1846.0    390.0    1775.0
# 4                482.0                  1705.0     94.0    1716.0
#
#    interpersonal_violence  ...  chronic_kidney_disease  poisonings  \
# 0                  3657.0  ...                  4490.0       512.0
# 1                  3785.0  ...                  4534.0       495.0
# ...

# %%
df["code"].value_counts()
# Out:
# BIH         30
# TUR         30
# PRI         30
# TGO         30
# LUX         30
#             ..
# OWID_USS     2
# WLF          1
# PYF          1
# GLP          1
# NCL          1
# Name: code, Length: 217, dtype: int64

# %%
len(df)
# Out:
# 7273

# %%
# df.iloc[0]

# %%
df.iloc[:, 2:10].head()
# Out:
#    year  meningitis  alzheimer's_diesease  parkinson's_disease  \
# 0  2007      2933.0                1402.0                450.0
# 1  2008      2731.0                1424.0                455.0
# 2  2009      2460.0                1449.0                460.0
# 3  2011      2327.0                1508.0                473.0
# 4  2012      2254.0                1544.0                482.0
#
#    nutritional_deficiency  malaria  drowning  interpersonal_violence
# 0                  2488.0    393.0    2127.0                  3657.0
# 1                  2277.0    255.0    1973.0                  3785.0
# 2                  2040.0    239.0    1852.0                  3874.0
# 3                  1846.0    390.0    1775.0                  4170.0
# 4                  1705.0     94.0    1716.0                  4245.0

# %%
df[df.isna().any(axis=1)]
# Out:
#                    country code  year  meningitis  alzheimer's_diesease  \
# 12             Afghanistan  AFG  1993      2812.0                1187.0
# 28             Afghanistan  AFG  2018      1576.0                1757.0
# 29             Afghanistan  AFG  2019      1563.0                1775.0
# 30    African Region (WHO)  NaN  1990    172206.0               24312.0
# 31    African Region (WHO)  NaN  1991    174087.0               25173.0
# ...                    ...  ...   ...         ...                   ...
# 7265              Zimbabwe  ZWE  2012      1586.0                 724.0
# 7268              Zimbabwe  ZWE  2015      1439.0                 754.0
# 7269              Zimbabwe  ZWE  2016      1457.0                 767.0
# 7271              Zimbabwe  ZWE  2018      1450.0                 795.0
# 7272              Zimbabwe  ZWE  2019      1450.0                 812.0
#
#       parkinson's_disease  nutritional_deficiency   malaria  drowning  \
# ...

# %%
df[["country", "code", "year"]].head()
# Out:
#        country code  year
# 0  Afghanistan  AFG  2007
# 1  Afghanistan  AFG  2008
# 2  Afghanistan  AFG  2009
# 3  Afghanistan  AFG  2011
# 4  Afghanistan  AFG  2012

# %%
df.columns
# Out:
# Index(['country', 'code', 'year', 'meningitis', 'alzheimer's_diesease',
#        'parkinson's_disease', 'nutritional_deficiency', 'malaria', 'drowning',
#        'interpersonal_violence', 'maternal_disorders', 'hiv/aids',
#        'drug_use_disorders', 'tuberculosis', 'cardiovascular_diseases',
#        'lower_respiratory_infections', 'neonatal_disorders',
#        'alcohol_use_disorders', 'self_harm', 'exposure_to_forces_of_nature',
#        'diarrheal_diseases', 'environmental_heat_and_cold_exposure',
#        'neoplasms', 'conflict_and_terrorism', 'diabetes_mellitus',
#        'chronic_kidney_disease', 'poisonings', 'protein_energy_malnutrition',
#        'terrorism', 'road_injuries', 'chronic_respiratory_diseases',
#        'chronic_liver_diseases', 'digestive_diseases',
#        'fire_heat_hot_substance', 'acute_hepatitis'],
#       dtype='object')

# %%
df.iloc[0]
# Out:
# country                                 Afghanistan
# code                                            AFG
# year                                           2007
# meningitis                                   2933.0
# alzheimer's_diesease                         1402.0
# parkinson's_disease                           450.0
# nutritional_deficiency                       2488.0
# malaria                                       393.0
# drowning                                     2127.0
# interpersonal_violence                       3657.0
# maternal_disorders                           4990.0
# hiv/aids                                      148.0
# drug_use_disorders                            252.0
# tuberculosis                                 4995.0
# cardiovascular_diseases                     53962.0
# lower_respiratory_infections                27672.0
# neonatal_disorders                          23890.0
# alcohol_use_disorders                         111.0
# ...

# %% [markdown]
# ### Get Total Death Per year

# %%
len(df.columns)
# Out:
# 35

# %%
df.iloc[:, 3:35].head()
# Out:
#    meningitis  alzheimer's_diesease  parkinson's_disease  \
# 0      2933.0                1402.0                450.0
# 1      2731.0                1424.0                455.0
# 2      2460.0                1449.0                460.0
# 3      2327.0                1508.0                473.0
# 4      2254.0                1544.0                482.0
#
#    nutritional_deficiency  malaria  drowning  interpersonal_violence  \
# 0                  2488.0    393.0    2127.0                  3657.0
# 1                  2277.0    255.0    1973.0                  3785.0
# 2                  2040.0    239.0    1852.0                  3874.0
# 3                  1846.0    390.0    1775.0                  4170.0
# 4                  1705.0     94.0    1716.0                  4245.0
#
#    maternal_disorders  hiv/aids  drug_use_disorders  ...  \
# 0              4990.0     148.0               252.0  ...
# 1              5020.0     157.0               261.0  ...
# ...

# %%
df["TotalDeaths"] = df.iloc[:, 3:35].sum(axis=1)

# %%
df[["country", "code", "year", "TotalDeaths"]].head()
# Out:
#        country code  year  TotalDeaths
# 0  Afghanistan  AFG  2007     204796.0
# 1  Afghanistan  AFG  2008     200209.0
# 2  Afghanistan  AFG  2009     195927.0
# 3  Afghanistan  AFG  2011     196559.0
# 4  Afghanistan  AFG  2012     200364.0

# %%
df.groupby(by=["year"], dropna=False).sum().iloc[0]

# %%
df.groupby(by=["country"], dropna=False).sum()
# Out:
#                        year  meningitis  alzheimer's_diesease  \
# country
# Afghanistan           60135     78666.0               41998.0
# African Region (WHO)  60135   5325372.0             1252189.0
# Albania               60135      1323.0               16549.0
# Algeria               60135     15685.0               86914.0
# American Samoa        60135        30.0                 143.0
# ...                     ...         ...                   ...
# Yemen                 60135     21095.0               31045.0
# Yugoslavia            23955         0.0                   0.0
# Zaire                 11965         0.0                   0.0
# Zambia                60135     98886.0               13473.0
# Zimbabwe              60135     41238.0               20017.0
#
#                       parkinson's_disease  nutritional_deficiency     malaria  \
# country
# Afghanistan                       13397.0                 71453.0     13924.0
# ...
